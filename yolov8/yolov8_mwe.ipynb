# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")
results = model("trafic.jpg", device="cpu")  # force CPU
results[0].save()
# Out:
# image 1/1 /home/user/development/lab/yolov8/trafic.jpg: 384x640 1 person, 1 car, 1 motorcycle, 3 trucks, 402.9ms
# Speed: 5.9ms preprocess, 402.9ms inference, 4.3ms postprocess per image at shape (1, 3, 384, 640)
# 'results_trafic.jpg'
