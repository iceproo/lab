# %% [markdown]
# Länk till YOLO NAS 2025
# https://www.labellerr.com/blog/ultimate-yolo-nas-guide/

# %%
# IMport from roboflow API
from roboflow import Roboflow

rf = Roboflow(api_key="940cpULjLlTyIVHebpd4")
project = rf.workspace("test-yn0ha").project("my-first-project-qaseg")
dataset = project.version(1).download("yolov8")  # YOLO format
print("Dataset: ", dataset.location)  # Dataset info
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dataset:  /home/c21/c21ion/edu/exjobb/lab/My-First-Project-1

# %%
from super_gradients.training import Trainer
from super_gradients.training.datasets import SimpleYOLODataset

dataset_path = dataset.location
# Paths to images and labels
train_images = f"{dataset_path}/train/images"
train_labels = f"{dataset_path}/train/labels"
val_images   = f"{dataset_path}/valid/images"
val_labels   = f"{dataset_path}/valid/labels"

# Create dataset objects
train_dataset = SimpleYOLODataset(images_dir=train_images, labels_dir=train_labels)
val_dataset   = SimpleYOLODataset(images_dir=val_images, labels_dir=val_labels)

# Initialize trainer
trainer = Trainer(experiment_name="yolo_nas_demo")

# Train YOLO NAS small model
trainer.train(
    model="yolo_nas_s",
    training_params={
        "lr_initial": 0.01,
        "max_epochs": 50,
        "batch_size": 16,
        "dataset": (train_dataset, val_dataset)
    }
)
# Out:
# Installing onnxruntime by `/home/c21/c21ion/.pyenv/versions/yolonas-env/bin/python -m pip install onnxruntime`,
# please wait for a moment..
# Requirement already satisfied: onnxruntime in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (1.15.0)
# Requirement already satisfied: coloredlogs in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (from onnxruntime) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (from onnxruntime) (25.9.23)
# Requirement already satisfied: numpy>=1.21.6 in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (from onnxruntime) (1.23.0)
# Requirement already satisfied: packaging in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (from onnxruntime) (25.0)
# Requirement already satisfied: protobuf in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (from onnxruntime) (3.20.3)
# Requirement already satisfied: sympy in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (from onnxruntime) (1.14.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (from coloredlogs->onnxruntime) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/c21/c21ion/.pyenv/versions/3.10.16/envs/yolonas-env/lib/python3.10/site-packages (from sympy->onnxruntime) (1.3.0)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxsim/onnx_simplifier.py:19
#      18 try:
# ---> 19     import onnxruntime as rt  # type: ignore
#      20 except ImportError:
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxruntime/__init__.py:55
#      54 if import_capi_exception:
# ---> 55     raise import_capi_exception
#      57 from onnxruntime.capi.onnxruntime_inference_collection import InferenceSession  # noqa: F401
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxruntime/__init__.py:23
#      22 try:
# ---> 23     from onnxruntime.capi._pybind_state import ExecutionMode  # noqa: F401
#      24     from onnxruntime.capi._pybind_state import ExecutionOrder  # noqa: F401
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxruntime/capi/_pybind_state.py:33
#      26             warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "
#      27                           "If you've installed the runtime in a non-standard location "
#      28                           "(other than %SystemRoot%\System32), "
#      29                           "make sure it can be found by setting the correct path.")
# ---> 33 from .onnxruntime_pybind11_state import *  # noqa
#
# ImportError: /home/c21/c21ion/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_pybind11_state.cpython-310-x86_64-linux-gnu.so: cannot enable executable stack as shared object requires: Invalid argument
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from super_gradients.training import Trainer
#       2 from super_gradients.training.datasets import SimpleYOLODataset
#       4 dataset_path = dataset.location
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/super_gradients/__init__.py:4
#       1 __version__ = "3.7.1"
#       3 from super_gradients.common import init_trainer, is_distributed, object_names
# ----> 4 from super_gradients.training import losses, utils, datasets_utils, DataAugmentation, Trainer, KDTrainer, QATTrainer
#       5 from super_gradients.common.registry.registry import ARCHITECTURES
#       6 from super_gradients.sanity_check import env_sanity_check
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/super_gradients/training/__init__.py:2
#       1 # PACKAGE IMPORTS FOR EXTERNAL USAGE
# ----> 2 import super_gradients.training.utils.distributed_training_utils as distributed_training_utils
#       3 from super_gradients.common import MultiGPUMode, StrictLoad, EvaluationType
#       4 from super_gradients.training.datasets import datasets_utils, DataAugmentation
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/super_gradients/training/utils/__init__.py:10
#       1 from super_gradients.training.utils.utils import (
#       2     Timer,
#       3     HpmStruct,
#    (...)
#       8     make_divisible,
#       9 )
# ---> 10 from super_gradients.training.utils.checkpoint_utils import adapt_state_dict_to_fit_model_layer_names, raise_informative_runtime_error
#      11 from super_gradients.training.utils.version_utils import torch_version_is_greater_or_equal
#      12 from super_gradients.training.utils.config_utils import raise_if_unused_params, warn_if_unused_params
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/super_gradients/training/utils/checkpoint_utils.py:14
#      12 from super_gradients.common.data_types import StrictLoad
#      13 from super_gradients.common.decorators.explicit_params_validator import explicit_params_validation
# ---> 14 from super_gradients.module_interfaces import HasPredict
#      15 from super_gradients.training.pretrained_models import MODEL_URLS, DATASET_LICENSES
#      16 from super_gradients.training.utils.distributed_training_utils import wait_for_the_master
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/super_gradients/module_interfaces/__init__.py:3
#       1 from .module_interfaces import HasPredict, HasPreprocessingParams, SupportsReplaceNumClasses, SupportsReplaceInputChannels, SupportsFineTune
#       2 from .exceptions import ModelHasNoPreprocessingParamsException
# ----> 3 from .exportable_detector import ExportableObjectDetectionModel, AbstractObjectDetectionDecodingModule, ObjectDetectionModelExportResult
#       4 from .exportable_pose_estimation import ExportablePoseEstimationModel, PoseEstimationModelExportResult, AbstractPoseEstimationDecodingModule
#       5 from .pose_estimation_post_prediction_callback import AbstractPoseEstimationPostPredictionCallback, PoseEstimationPredictions
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/super_gradients/module_interfaces/exportable_detector.py:10
#       8 import numpy as np
#       9 import onnx
# ---> 10 import onnxsim
#      11 import torch
#      12 from super_gradients.common.abstractions.abstract_logger import get_logger
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxsim/__init__.py:1
# ----> 1 from onnxsim.onnx_simplifier import simplify, main
#       3 # register python executor
#       4 import onnxsim.onnx_simplifier
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxsim/onnx_simplifier.py:25
#      23     import subprocess
#      24     subprocess.check_call(command)
# ---> 25     import onnxruntime as rt
#      28 import onnxsim.onnxsim_cpp2py_export as C
#      29 from . import model_info
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxruntime/__init__.py:55
#      52 from onnxruntime.capi import onnxruntime_validation
#      54 if import_capi_exception:
# ---> 55     raise import_capi_exception
#      57 from onnxruntime.capi.onnxruntime_inference_collection import InferenceSession  # noqa: F401
#      58 from onnxruntime.capi.onnxruntime_inference_collection import IOBinding  # noqa: F401
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxruntime/__init__.py:23
#      13 # we need to do device version validation (for example to check Cuda version for an onnxruntime-training package).
#      14 # in order to know whether the onnxruntime package is for training it needs
#      15 # to do import onnxruntime.training.ortmodule first.
#    (...)
#      20 # meaningful messages to the user.
#      21 # the saved exception is raised after device version validation.
#      22 try:
# ---> 23     from onnxruntime.capi._pybind_state import ExecutionMode  # noqa: F401
#      24     from onnxruntime.capi._pybind_state import ExecutionOrder  # noqa: F401
#      25     from onnxruntime.capi._pybind_state import GraphOptimizationLevel  # noqa: F401
#
# File ~/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxruntime/capi/_pybind_state.py:33
#      25         if not os.path.isfile(os.path.join(system_root, "System32", "vcruntime140_1.dll")):
#      26             warnings.warn("Please install the 2019 Visual C++ runtime and then try again. "
#      27                           "If you've installed the runtime in a non-standard location "
#      28                           "(other than %SystemRoot%\System32), "
#      29                           "make sure it can be found by setting the correct path.")
# ---> 33 from .onnxruntime_pybind11_state import *  # noqa
#
# ImportError: /home/c21/c21ion/.pyenv/versions/yolonas-env/lib/python3.10/site-packages/onnxruntime/capi/onnxruntime_pybind11_state.cpython-310-x86_64-linux-gnu.so: cannot enable executable stack as shared object requires: Invalid argument
